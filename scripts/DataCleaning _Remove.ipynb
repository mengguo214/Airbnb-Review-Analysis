# %%
from langdetect import detect
import pandas as pd

# %%
df_review=pd.read_csv("./reviews.csv/reviews.csv")
df_review.dropna()
# Out:
#         listing_id         id        date  reviewer_id     reviewer_name  \
# 0              958       5977  2009-07-23        15695          Edmund C
# 1              958       6660  2009-08-03        26145             Simon
# 2              958      11519  2009-09-27        25839             Denis
# 3              958      16282  2009-11-05        33750              Anna
# 4              958      26008  2010-02-13        15416           Venetia
# 5              958      29240  2010-03-13        78623           Mathieu
# 6              958      32988  2010-04-03        96027            Lauren
# 7              958     220443  2011-04-08       426888          Michelle
# 8              958     567690  2011-09-26       539189             Sarah
# 9              958    1786860  2012-07-24      2059845              Jörg
# 10             958    2214082  2012-09-06      2869693            Carrie
# 11             958    2263537  2012-09-11      2953444          Adrienne
# ...

# %%
def trans(text):
    textresult=type(text).__name__
    return(textresult)

# %%
df_review["type"]=df_review.comments.apply(trans)

# %%
df_review
df_review=df_review[df_review["type"]=="str"]
df_review
# Out:
#         listing_id         id        date  reviewer_id     reviewer_name  \
# 0              958       5977  2009-07-23        15695          Edmund C
# 1              958       6660  2009-08-03        26145             Simon
# 2              958      11519  2009-09-27        25839             Denis
# 3              958      16282  2009-11-05        33750              Anna
# 4              958      26008  2010-02-13        15416           Venetia
# 5              958      29240  2010-03-13        78623           Mathieu
# 6              958      32988  2010-04-03        96027            Lauren
# 7              958     220443  2011-04-08       426888          Michelle
# 8              958     567690  2011-09-26       539189             Sarah
# 9              958    1786860  2012-07-24      2059845              Jörg
# 10             958    2214082  2012-09-06      2869693            Carrie
# 11             958    2263537  2012-09-11      2953444          Adrienne
# ...

# %%
df_review["len"]=df_review.comments.apply(len)
df_review=df_review[df_review['len']>10]

# %%
df_review
# Out:
#         listing_id         id        date  reviewer_id     reviewer_name  \
# 0              958       5977  2009-07-23        15695          Edmund C
# 1              958       6660  2009-08-03        26145             Simon
# 2              958      11519  2009-09-27        25839             Denis
# 3              958      16282  2009-11-05        33750              Anna
# 4              958      26008  2010-02-13        15416           Venetia
# 5              958      29240  2010-03-13        78623           Mathieu
# 6              958      32988  2010-04-03        96027            Lauren
# 7              958     220443  2011-04-08       426888          Michelle
# 8              958     567690  2011-09-26       539189             Sarah
# 9              958    1786860  2012-07-24      2059845              Jörg
# 10             958    2214082  2012-09-06      2869693            Carrie
# 11             958    2263537  2012-09-11      2953444          Adrienne
# ...

# %%
#df_review=df_review.iloc[:10000]
df_review[["listing_id","comments"]]
df_review["detect"]=df_review.comments.apply(detect)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_review
# Out:
#         listing_id         id        date  reviewer_id     reviewer_name  \
# 0              958       5977  2009-07-23        15695          Edmund C
# 1              958       6660  2009-08-03        26145             Simon
# 2              958      11519  2009-09-27        25839             Denis
# 3              958      16282  2009-11-05        33750              Anna
# 4              958      26008  2010-02-13        15416           Venetia
# 5              958      29240  2010-03-13        78623           Mathieu
# 6              958      32988  2010-04-03        96027            Lauren
# 7              958     220443  2011-04-08       426888          Michelle
# 8              958     567690  2011-09-26       539189             Sarah
# 9              958    1786860  2012-07-24      2059845              Jörg
# 10             958    2214082  2012-09-06      2869693            Carrie
# 11             958    2263537  2012-09-11      2953444          Adrienne
# ...

# %%
df_review=df_review[df_review["detect"]=="en"]

# %%
df_review
# Out:
#         listing_id         id        date  reviewer_id     reviewer_name  \
# 0              958       5977  2009-07-23        15695          Edmund C
# 1              958       6660  2009-08-03        26145             Simon
# 2              958      11519  2009-09-27        25839             Denis
# 3              958      16282  2009-11-05        33750              Anna
# 4              958      26008  2010-02-13        15416           Venetia
# 5              958      29240  2010-03-13        78623           Mathieu
# 6              958      32988  2010-04-03        96027            Lauren
# 7              958     220443  2011-04-08       426888          Michelle
# 8              958     567690  2011-09-26       539189             Sarah
# 9              958    1786860  2012-07-24      2059845              Jörg
# 10             958    2214082  2012-09-06      2869693            Carrie
# 11             958    2263537  2012-09-11      2953444          Adrienne
# ...

# %%
df_review.to_csv("review_complete.csv")
